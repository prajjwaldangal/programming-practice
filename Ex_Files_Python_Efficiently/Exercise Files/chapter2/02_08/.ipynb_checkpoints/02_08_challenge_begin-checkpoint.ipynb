# %% [markdown]
# ### Python module/package imports for this chapter

# %%
import math, json, collections, itertools

# %%
import numpy as np
import matplotlib.pyplot as pp
# %matplotlib inline

# %%
from mpl_toolkits.basemap import Basemap
import geopy

# %% [markdown]
# ### Code and data needed from previous videos

# %%
medal = collections.namedtuple('medal',['year','athlete','team','event'])
medals = [medal(*line.strip().split('\t')) for line in open('goldmedals.txt','r')]

# %% [markdown]
# ## Challenge solution

# %%
# Out:
# [medal(year='1896', athlete='Thomas Burke', team='USA', event='100m men'),
#  medal(year='1896', athlete='Thomas Curtis', team='USA', event='110m hurdles men'),
#  medal(year='1896', athlete='Edwin Flack', team='AUS', event='1500m men'),
#  medal(year='1896', athlete='Thomas Burke', team='USA', event='400m men'),
#  medal(year='1896', athlete='Edwin Flack', team='AUS', event='800m men'),
#  medal(year='1896', athlete='Robert Garrett', team='USA', event='discus throw men'),
#  medal(year='1896', athlete='Ellery Clark', team='USA', event='high jump men'),
#  medal(year='1896', athlete='Ellery Clark', team='USA', event='long jump men'),
#  medal(year='1896', athlete='Spyridon Louis', team='GRE', event='marathon men'),
#  medal(year='1896', athlete='William Welles Hoyt', team='USA', event='pole vault men'),
#  medal(year='1896', athlete='Robert Garrett', team='USA', event='shot put men'),
#  medal(year='1896', athlete='James Connolly', team='USA', event='triple jump men'),
#  medal(year='1900', athlete='Francis Jarvis', team='USA', event='100m men'),
#  medal(year='1900', athlete='Alvin Kraenzlein', team='USA', event='110m hurdles men'),
#  medal(year='1900', athlete='Charles Bennett', team='GBR', event='1500m men'),
#  medal(year='1900', athlete='Walter B. John Tewksbury', team='USA', event='200m men'),
#  medal(year='1900', athlete='Alvin Kraenzlein', team='USA', event='200m hurdles men'),
#  medal(year='1900', athlete='George Orton', team='CAN', event='3000m steeplechase men'),
#  medal(year='1900', athlete='John Rimmer', team='GBR', event='4000m steeplechase men'),
#  medal(year='1900', athlete='Maxwell W.Maxey Long', team='USA', event='400m men'),
#  medal(year='1900', athlete='Walter B. John Tewksbury', team='USA', event='400m hurdles men'),
#  medal(year='1900', athlete='Charles Bennett', team='ZZX', event='5000m team men'),
#  medal(year='1900', athlete='John Rimmer', team='ZZX', event='5000m team men'),
#  medal(year='1900', athlete='Sidney Robinson', team='ZZX', event='5000m team men'),
#  medal(year='1900', athlete='Stanley Rowley', team='ZZX', event='5000m team men'),
#  medal(year='1900', athlete='Alfred Tysoe', team='ZZX', event='5000m team men'),
#  medal(year='1900', athlete='Alvin Kraenzlein', team='USA', event='60m men'),
#  medal(year='1900', athlete='Alfred Tysoe', team='GBR', event='800m men'),
#  medal(year='1900', athlete='Rudolf Bauer', team='HUN', event='discus throw men'),
#  medal(year='1900', athlete='John Jesus Flanagan', team='USA', event='hammer throw men'),
#  medal(year='1900', athlete='Irving Baxter', team='USA', event='high jump men'),
#  medal(year='1900', athlete='Ray Ewry', team='USA', event='high jump, standing men'),
#  medal(year='1900', athlete='Alvin Kraenzlein', team='USA', event='long jump men'),
#  medal(year='1900', athlete='Ray Ewry', team='USA', event='long jump, standing men'),
#  medal(year='1900', athlete='Michel Theato', team='FRA', event='marathon men'),
#  medal(year='1900', athlete='Irving Baxter', team='USA', event='pole vault men'),
#  medal(year='1900', athlete='Richard Sheldon', team='USA', event='shot put men'),
#  medal(year='1900', athlete='Meyer Prinstein', team='USA', event='triple jump men'),
#  medal(year='1900', athlete='Ray Ewry', team='USA', event='triple jump, standing men'),
#  medal(year='1904', athlete='Archie Hahn', team='USA', event='100m men'),
#  medal(year='1904', athlete='Frederick Schule', team='USA', event='110m hurdles men'),
#  medal(year='1904', athlete='James Lightbody', team='USA', event='1500m men'),
#  medal(year='1904', athlete='Archie Hahn', team='USA', event='200m men'),
#  medal(year='1904', athlete='Harry Hillman', team='USA', event='200m hurdles men'),
#  medal(year='1904', athlete='James Lightbody', team='USA', event='3000m steeplechase men'),
#  medal(year='1904', athlete='Harry Hillman', team='USA', event='400m men'),
#  medal(year='1904', athlete='Harry Hillman', team='USA', event='400m hurdles men'),
#  medal(year='1904', athlete='David Curtis Munson', team='USA', event='4miles team men'),
#  medal(year='1904', athlete='Arthur Newton', team='USA', event='4miles team men'),
#  medal(year='1904', athlete='Paul Harry Pilgrim', team='USA', event='4miles team men'),
#  medal(year='1904', athlete='George Underwood', team='USA', event='4miles team men'),
#  medal(year='1904', athlete='Howard Valentine', team='USA', event='4miles team men'),
#  medal(year='1904', athlete='Etienne Desmarteau', team='CAN', event='56lb weight throw (25.4kg) men'),
#  medal(year='1904', athlete='Archie Hahn', team='USA', event='60m men'),
#  medal(year='1904', athlete='James Lightbody', team='USA', event='800m men'),
#  medal(year='1904', athlete='Thomas Francis Kiely', team='GBR', event='decathlon men'),
#  medal(year='1904', athlete='Martin Sheridan', team='USA', event='discus throw men'),
#  medal(year='1904', athlete='John Jesus Flanagan', team='USA', event='hammer throw men'),
#  medal(year='1904', athlete='Samuel Jones', team='USA', event='high jump men'),
#  medal(year='1904', athlete='Ray Ewry', team='USA', event='high jump, standing men'),
#  medal(year='1904', athlete='Meyer Prinstein', team='USA', event='long jump men'),
#  medal(year='1904', athlete='Ray Ewry', team='USA', event='long jump, standing men'),
#  medal(year='1904', athlete='Thomas Hicks', team='USA', event='marathon men'),
#  medal(year='1904', athlete='Charles Dvorak', team='USA', event='pole vault men'),
#  medal(year='1904', athlete='Ralph Rose', team='USA', event='shot put men'),
#  medal(year='1904', athlete='Max Emmerich', team='USA', event='triathlon (long jump / shot put / 100 yards) men'),
#  medal(year='1904', athlete='Meyer Prinstein', team='USA', event='triple jump men'),
#  medal(year='1904', athlete='Ray Ewry', team='USA', event='triple jump, standing men'),
#  medal(year='1908', athlete='Reginald Walker', team='RSA', event='100m men'),
#  medal(year='1908', athlete='George Edward Larner', team='GBR', event='10miles walk (16093m) men'),
#  medal(year='1908', athlete='Forrest Smithson', team='USA', event='110m hurdles men'),
#  medal(year='1908', athlete='Melvin Sheppard', team='USA', event='1500m men'),
#  medal(year='1908', athlete='Robert Kerr', team='CAN', event='200m men'),
#  medal(year='1908', athlete='Arthur Russell', team='GBR', event='3200m steeplechase men'),
#  medal(year='1908', athlete='George Edward Larner', team='GBR', event='3500m walk men'),
#  medal(year='1908', athlete='William Coales', team='GBR', event='3miles team (4828m) men'),
#  medal(year='1908', athlete='Joseph Edmund Deakin', team='GBR', event='3miles team (4828m) men'),
#  medal(year='1908', athlete='Arthur James Robertson', team='GBR', event='3miles team (4828m) men'),
#  medal(year='1908', athlete='Wyndham Halswelle', team='GBR', event='400m men'),
#  medal(year='1908', athlete='Charles Joseph Bacon', team='USA', event='400m hurdles men'),
#  medal(year='1908', athlete='John Nathaniel Cartmell', team='USA', event='4x400m relay men'),
#  medal(year='1908', athlete='William Frank Hamilton', team='USA', event='4x400m relay men'),
#  medal(year='1908', athlete='Melvin Sheppard', team='USA', event='4x400m relay men'),
#  medal(year='1908', athlete='John Baxter Taylor', team='USA', event='4x400m relay men'),
#  medal(year='1908', athlete='Emil Robert Voigt', team='GBR', event='5 miles (8047m) men'),
#  medal(year='1908', athlete='Melvin Sheppard', team='USA', event='800m men'),
#  medal(year='1908', athlete='Martin Sheridan', team='USA', event='discus throw men'),
#  medal(year='1908', athlete='Martin Sheridan', team='USA', event='discus throw ancient style men'),
#  medal(year='1908', athlete='John Jesus Flanagan', team='USA', event='hammer throw men'),
#  medal(year='1908', athlete='Harry Franklin Porter', team='USA', event='high jump men'),
#  medal(year='1908', athlete='Ray Ewry', team='USA', event='high jump, standing men'),
#  medal(year='1908', athlete='Eric Lemming', team='SWE', event='javelin throw men'),
#  medal(year='1908', athlete='Eric Lemming', team='SWE', event='javelin throw freestyle men'),
#  medal(year='1908', athlete='Francis C. Irons', team='USA', event='long jump men'),
#  medal(year='1908', athlete='Ray Ewry', team='USA', event='long jump, standing men'),
#  medal(year='1908', athlete='John Joseph Hayes', team='USA', event='marathon men'),
#  medal(year='1908', athlete='Edward Tiffin Cooke', team='USA', event='pole vault men'),
#  medal(year='1908', athlete='Alfred Carleten Gilbert', team='USA', event='pole vault men'),
#  medal(year='1908', athlete='Ralph Rose', team='USA', event='shot put men'),
#  medal(year='1908', athlete='Timoty J. Ahearne', team='GBR', event='triple jump men'),
#  medal(year='1912', athlete='Hannes Kolehmainen', team='FIN', event='10000m men'),
#  medal(year='1912', athlete='George Goulding', team='CAN', event='10000m walk men'),
#  medal(year='1912', athlete='Ralph Craig', team='USA', event='100m men'),
#  medal(year='1912', athlete='Frederick Kelly', team='USA', event='110m hurdles men'),
#  medal(year='1912', athlete='Arnold Jackson', team='GBR', event='1500m men'),
#  medal(year='1912', athlete='Ralph Craig', team='USA', event='200m men'),
#  medal(year='1912', athlete='Tell Schirnding Berna', team='USA', event='3000m team men'),
#  medal(year='1912', athlete='George V. Bonhag', team='USA', event='3000m team men'),
#  medal(year='1912', athlete='Abel Kiviat', team='USA', event='3000m team men'),
#  medal(year='1912', athlete='Henry Louis Scott', team='USA', event='3000m team men'),
#  medal(year='1912', athlete='Norman Taber', team='USA', event='3000m team men'),
#  medal(year='1912', athlete='Charles Decker Reidpath', team='USA', event='400m men'),
#  medal(year='1912', athlete='William Applegarth', team='GBR', event='4x100m relay men'),
#  medal(year='1912', athlete="Victor Henry Augustus D'arcy", team='GBR', event='4x100m relay men'),
#  medal(year='1912', athlete='David Henry Jacobs', team='GBR', event='4x100m relay men'),
#  medal(year='1912', athlete='Henry Maitland Mackintosh', team='GBR', event='4x100m relay men'),
#  medal(year='1912', athlete='Edward F. Lindberg', team='USA', event='4x400m relay men'),
#  medal(year='1912', athlete='James Edwin Meredith', team='USA', event='4x400m relay men'),
#  medal(year='1912', athlete='Charles Decker Reidpath', team='USA', event='4x400m relay men'),
#  medal(year='1912', athlete='Melvin Sheppard', team='USA', event='4x400m relay men'),
#  medal(year='1912', athlete='Hannes Kolehmainen', team='FIN', event='5000m men'),
#  medal(year='1912', athlete='James Edwin Meredith', team='USA', event='800m men'),
#  medal(year='1912', athlete='Hannes Kolehmainen', team='FIN', event='cross country individual men'),
#  medal(year='1912', athlete='Hjalmar Andersson', team='SWE', event='cross country team men'),
#  medal(year='1912', athlete='John Eke', team='SWE', event='cross country team men'),
#  medal(year='1912', athlete='Josef Ternström', team='SWE', event='cross country team men'),
#  medal(year='1912', athlete='Jim Thorpe', team='USA', event='decathlon men'),
#  medal(year='1912', athlete='Hugo K. Wieslander', team='SWE', event='decathlon men'),
#  medal(year='1912', athlete='Armas Rudolf Taipale', team='FIN', event='discus throw men'),
#  medal(year='1912', athlete='Armas Rudolf Taipale', team='FIN', event='discus throw, both hands men'),
#  medal(year='1912', athlete='Matthew J. Mcgrath', team='USA', event='hammer throw men'),
#  medal(year='1912', athlete='Alma Wilfred Richards', team='USA', event='high jump men'),
#  medal(year='1912', athlete='Platt Adams', team='USA', event='high jump, standing men'),
#  medal(year='1912', athlete='Eric Lemming', team='SWE', event='javelin throw men'),
#  medal(year='1912', athlete='Juho Julius Saaristo', team='FIN', event='javelin throw, both hands men'),
#  medal(year='1912', athlete='Albert Lovejoy Gutterson', team='USA', event='long jump men'),
#  medal(year='1912', athlete='Konstantinos Tsiclitiras', team='GRE', event='long jump, standing men'),
#  medal(year='1912', athlete='Kennedy Kane Mcarthur', team='RSA', event='marathon men'),
#  medal(year='1912', athlete='Ferdinand Reinhardt Bie', team='NOR', event='pentathlon men'),
#  medal(year='1912', athlete='Jim Thorpe', team='USA', event='pentathlon men'),
#  medal(year='1912', athlete='Harry Stoddard Babcock', team='USA', event='pole vault men'),
#  medal(year='1912', athlete='Patrick Mcdonald', team='USA', event='shot put men'),
#  medal(year='1912', athlete='Ralph Rose', team='USA', event='shot put, both hands men'),
#  medal(year='1912', athlete='Gustav Lindblom', team='SWE', event='triple jump men'),
#  medal(year='1920', athlete='Paavo Nurmi', team='FIN', event='10000m men'),
#  medal(year='1920', athlete='Ugo Frigerio', team='ITA', event='10000m walk men'),
#  medal(year='1920', athlete='Charles Paddock', team='USA', event='100m men'),
#  medal(year='1920', athlete='Earl Thomson', team='CAN', event='110m hurdles men'),
#  medal(year='1920', athlete='Albert Hill', team='GBR', event='1500m men'),
#  medal(year='1920', athlete='Allen Woodring', team='USA', event='200m men'),
#  medal(year='1920', athlete='Percy Hodge', team='GBR', event='3000m steeplechase men'),
#  medal(year='1920', athlete='Horace Hallock Brown', team='USA', event='3000m team men'),
#  medal(year='1920', athlete='Ivan Dresser', team='USA', event='3000m team men'),
#  medal(year='1920', athlete='Arlie Alfred Schardt', team='USA', event='3000m team men'),
#  medal(year='1920', athlete='Ugo Frigerio', team='ITA', event='3000m walk men'),
#  medal(year='1920', athlete="Bevil Gordon D'Urban Rudd", team='RSA', event='400m men'),
#  medal(year='1920', athlete='Frank Loomis', team='USA', event='400m hurdles men'),
#  medal(year='1920', athlete='Morris Kirksey', team='USA', event='4x100m relay men'),
#  medal(year='1920', athlete='Loren Murchison', team='USA', event='4x100m relay men'),
#  medal(year='1920', athlete='Charles Paddock', team='USA', event='4x100m relay men'),
#  medal(year='1920', athlete='Jackson Scholz', team='USA', event='4x100m relay men'),
#  medal(year='1920', athlete='John Creyghton Ainsworth-Davis', team='GBR', event='4x400m relay men'),
#  medal(year='1920', athlete='Guy Montagu Butler', team='GBR', event='4x400m relay men'),
#  medal(year='1920', athlete='Cecil Richmond Griffiths', team='GBR', event='4x400m relay men'),
#  medal(year='1920', athlete='Robert Alexander Lindsay', team='GBR', event='4x400m relay men'),
#  medal(year='1920', athlete='Joseph Guillemot', team='FRA', event='5000m men'),
#  medal(year='1920', athlete='Patrick Mcdonald', team='USA', event='56lb weight throw (25.4kg) men'),
#  medal(year='1920', athlete='Albert Hill', team='GBR', event='800m men'),
#  medal(year='1920', athlete='Paavo Nurmi', team='FIN', event='cross country individual men'),
#  medal(year='1920', athlete='Frederik Teudor Koskenniemi', team='FIN', event='cross country team men'),
#  medal(year='1920', athlete='Heikki Liimatainen', team='FIN', event='cross country team men'),
#  medal(year='1920', athlete='Paavo Nurmi', team='FIN', event='cross country team men'),
#  medal(year='1920', athlete='Helge Andreas Lövland', team='NOR', event='decathlon men'),
#  medal(year='1920', athlete='Elmer Konstantin Niklander', team='FIN', event='discus throw men'),
#  medal(year='1920', athlete='Patrick Ryan', team='USA', event='hammer throw men'),
#  medal(year='1920', athlete='Richmond Landon', team='USA', event='high jump men'),
#  medal(year='1920', athlete='Jonni Myyrä', team='FIN', event='javelin throw men'),
#  medal(year='1920', athlete='R. William E. Petersson', team='SWE', event='long jump men'),
#  medal(year='1920', athlete='Hannes Kolehmainen', team='FIN', event='marathon men'),
#  medal(year='1920', athlete='Eero Reino Lehtonen', team='FIN', event='pentathlon men'),
#  medal(year='1920', athlete='Frank Foss', team='USA', event='pole vault men'),
#  medal(year='1920', athlete='Frans Wilhelmi Pörhölä', team='FIN', event='shot put men'),
#  medal(year='1920', athlete='Vilho Immanuel Tuulos', team='FIN', event='triple jump men'),
#  medal(year='1924', athlete='Ville Ritola', team='FIN', event='10000m men'),
#  medal(year='1924', athlete='Ugo Frigerio', team='ITA', event='10000m walk men'),
#  medal(year='1924', athlete='Harold Abrahams', team='GBR', event='100m men'),
#  medal(year='1924', athlete='Daniel Kinsey', team='USA', event='110m hurdles men'),
#  medal(year='1924', athlete='Paavo Nurmi', team='FIN', event='1500m men'),
#  medal(year='1924', athlete='Jackson Scholz', team='USA', event='200m men'),
#  medal(year='1924', athlete='Ville Ritola', team='FIN', event='3000m steeplechase men'),
#  medal(year='1924', athlete='Elias Katz', team='FIN', event='3000m team men'),
#  medal(year='1924', athlete='Frej Liewendhal', team='FIN', event='3000m team men'),
#  medal(year='1924', athlete='Paavo Nurmi', team='FIN', event='3000m team men'),
#  medal(year='1924', athlete='Ville Ritola', team='FIN', event='3000m team men'),
#  medal(year='1924', athlete='Eino Seppälä', team='FIN', event='3000m team men'),
#  medal(year='1924', athlete='S. Talja', team='FIN', event='3000m team men'),
#  medal(year='1924', athlete='Eric Henry Liddell', team='GBR', event='400m men'),
#  medal(year='1924', athlete='Frederick Morgan Taylor', team='USA', event='400m hurdles men'),
#  medal(year='1924', athlete='Louis Alfred Clarke', team='USA', event='4x100m relay men'),
#  medal(year='1924', athlete='Francis Hussey', team='USA', event='4x100m relay men'),
#  medal(year='1924', athlete='Jeremiah Alfred Leconey', team='USA', event='4x100m relay men'),
#  medal(year='1924', athlete='Loren Murchison', team='USA', event='4x100m relay men'),
#  medal(year='1924', athlete='Commodore Cochrane', team='USA', event='4x400m relay men'),
#  medal(year='1924', athlete='Alan Helffrich', team='USA', event='4x400m relay men'),
#  medal(year='1924', athlete='J. Oliver Macdonald', team='USA', event='4x400m relay men'),
#  medal(year='1924', athlete='William Stephenson', team='USA', event='4x400m relay men'),
#  medal(year='1924', athlete='Paavo Nurmi', team='FIN', event='5000m men'),
#  medal(year='1924', athlete='Douglas Gordon Lowe', team='GBR', event='800m men'),
#  medal(year='1924', athlete='Paavo Nurmi', team='FIN', event='cross country individual men'),
#  medal(year='1924', athlete='Eero Berg', team='FIN', event='cross country team men'),
#  medal(year='1924', athlete='Heikki Liimatainen', team='FIN', event='cross country team men'),
#  medal(year='1924', athlete='Paavo Nurmi', team='FIN', event='cross country team men'),
#  medal(year='1924', athlete='Eino Rastas', team='FIN', event='cross country team men'),
#  medal(year='1924', athlete='Ville Ritola', team='FIN', event='cross country team men'),
#  medal(year='1924', athlete='Väinö Jeremias Sipilä', team='FIN', event='cross country team men'),
#  medal(year='1924', athlete='Harold Marion Osborn', team='USA', event='decathlon men'),
#  medal(year='1924', athlete='Lemuel Clarence Houser', team='USA', event='discus throw men'),
#  medal(year='1924', athlete='Frederick Delmont Tootell', team='USA', event='hammer throw men'),
#  medal(year='1924', athlete='Harold Marion Osborn', team='USA', event='high jump men'),
#  medal(year='1924', athlete='Jonni Myyrä', team='FIN', event='javelin throw men'),
#  medal(year='1924', athlete='William De Hart Hubbard', team='USA', event='long jump men'),
#  medal(year='1924', athlete='Albin Oskar Stenroos', team='FIN', event='marathon men'),
#  medal(year='1924', athlete='Eero Reino Lehtonen', team='FIN', event='pentathlon men'),
#  medal(year='1924', athlete='Lee Barnes', team='USA', event='pole vault men'),
#  medal(year='1924', athlete='Lemuel Clarence Houser', team='USA', event='shot put men'),
#  medal(year='1924', athlete='Anthony William Winter', team='AUS', event='triple jump men'),
#  medal(year='1928', athlete='Paavo Nurmi', team='FIN', event='10000m men'),
#  medal(year='1928', athlete='Percy Williams', team='CAN', event='100m men'),
#  medal(year='1928', athlete='Elizabeth Robinson', team='USA', event='100m women'),
#  medal(year='1928', athlete='Sidney Atkinson', team='RSA', event='110m hurdles men'),
#  medal(year='1928', athlete='Harri Edvin Larva', team='FIN', event='1500m men'),
#  medal(year='1928', athlete='Percy Williams', team='CAN', event='200m men'),
#  medal(year='1928', athlete='Toivo Aarne Loukola', team='FIN', event='3000m steeplechase men'),
#  medal(year='1928', athlete='Raymond James Barbuti', team='USA', event='400m men'),
#  medal(year='1928', athlete='David George Burghley', team='GBR', event='400m hurdles men'),
#  medal(year='1928', athlete='Charles Edward Borah', team='USA', event='4x100m relay men'),
#  medal(year='1928', athlete='James F. Quinn', team='USA', event='4x100m relay men'),
#  medal(year='1928', athlete='Henry Argue Russell', team='USA', event='4x100m relay men'),
#  medal(year='1928', athlete='Frank Clifford Wykoff', team='USA', event='4x100m relay men'),
#  medal(year='1928', athlete='Myrtle Alice Cook', team='CAN', event='4x100m relay women'),
#  medal(year='1928', athlete='Fanny Rosenfeld', team='CAN', event='4x100m relay women'),
#  medal(year='1928', athlete='Ethel M. Smith', team='CAN', event='4x100m relay women'),
#  medal(year='1928', athlete='Jean Thompson', team='CAN', event='4x100m relay women'),
#  medal(year='1928', athlete='Frederick Pitt Alderman', team='USA', event='4x400m relay men'),
#  medal(year='1928', athlete='George Hetzel Baird', team='USA', event='4x400m relay men'),
#  medal(year='1928', athlete='Raymond James Barbuti', team='USA', event='4x400m relay men'),
#  medal(year='1928', athlete='Emerson Lane Spencer', team='USA', event='4x400m relay men'),
#  medal(year='1928', athlete='Ville Ritola', team='FIN', event='5000m men'),
#  medal(year='1928', athlete='Douglas Gordon Lowe', team='GBR', event='800m men'),
#  medal(year='1928', athlete='Karoline "Lina" Radke', team='GER', event='800m women'),
#  medal(year='1928', athlete='Paavo Ilmari Yrjölä', team='FIN', event='decathlon men'),
#  medal(year='1928', athlete='Lemuel Clarence Houser', team='USA', event='discus throw men'),
#  medal(year='1928', athlete='Halina Konopacka', team='POL', event='discus throw women'),
#  medal(year='1928', athlete="Patrick O'callaghan", team='IRL', event='hammer throw men'),
#  medal(year='1928', athlete='Robert Wade King', team='USA', event='high jump men'),
#  medal(year='1928', athlete='Ethel Catherwood', team='CAN', event='high jump women'),
#  medal(year='1928', athlete='Erik H. Lundqvist', team='SWE', event='javelin throw men'),
#  medal(year='1928', athlete='Edward Barton Hamm', team='USA', event='long jump men'),
#  medal(year='1928', athlete='Boughera Mohamed El Ouafi', team='FRA', event='marathon men'),
#  medal(year='1928', athlete='Sabin William Carr', team='USA', event='pole vault men'),
#  medal(year='1928', athlete='John H. Kuck', team='USA', event='shot put men'),
#  medal(year='1928', athlete='Mikio Oda', team='JPN', event='triple jump men'),
#  medal(year='1932', athlete='Janusz Kusocinski', team='POL', event='10000m men'),
#  medal(year='1932', athlete='Eddie Tolan', team='USA', event='100m men'),
#  medal(year='1932', athlete='Stanislawa Walasiewicz', team='POL', event='100m women'),
#  medal(year='1932', athlete='George J. Jr. Saling', team='USA', event='110m hurdles men'),
#  medal(year='1932', athlete='Luigi Beccali', team='ITA', event='1500m men'),
#  medal(year='1932', athlete='Eddie Tolan', team='USA', event='200m men'),
#  medal(year='1932', athlete='Volmari Iso-Hollo', team='FIN', event='3000m steeplechase men'),
#  medal(year='1932', athlete='William Arthur Carr', team='USA', event='400m men'),
#  medal(year='1932', athlete='Robert Morton Newburgh Tisdall', team='IRL', event='400m hurdles men'),
#  medal(year='1932', athlete='Hector Monroe Dyer', team='USA', event='4x100m relay men'),
#  medal(year='1932', athlete='Robert Allan Kiesel', team='USA', event='4x100m relay men'),
#  medal(year='1932', athlete='Martin Emmett Toppino', team='USA', event='4x100m relay men'),
#  medal(year='1932', athlete='Frank Clifford Wykoff', team='USA', event='4x100m relay men'),
#  medal(year='1932', athlete='Mary Louise Carew', team='USA', event='4x100m relay women'),
#  medal(year='1932', athlete='Evelyn Furtsch', team='USA', event='4x100m relay women'),
#  medal(year='1932', athlete='Annette Joan Rogers', team='USA', event='4x100m relay women'),
#  medal(year='1932', athlete='Wilhelmina Von bremen', team='USA', event='4x100m relay women'),
#  medal(year='1932', athlete='Edgar Allen Ablowich', team='USA', event='4x400m relay men'),
#  medal(year='1932', athlete='William Arthur Carr', team='USA', event='4x400m relay men'),
#  medal(year='1932', athlete='Ivan William Fuqua', team='USA', event='4x400m relay men'),
#  medal(year='1932', athlete='Karl De Witt Warner', team='USA', event='4x400m relay men'),
#  medal(year='1932', athlete='Lauri Aleksanteri Lehtinen', team='FIN', event='5000m men'),
#  medal(year='1932', athlete='Thomas William Green', team='GBR', event='50km walk men'),
#  medal(year='1932', athlete='Thomas Hampson', team='GBR', event='800m men'),
#  medal(year='1932', athlete='Mildred Didrikson', team='USA', event='80m hurdles women'),
#  medal(year='1932', athlete='James Aloysius Bernard Bausch', team='USA', event='decathlon men'),
#  medal(year='1932', athlete='John Franklin Anderson', team='USA', event='discus throw men'),
#  medal(year='1932', athlete='Lillian Copeland', team='USA', event='discus throw women'),
#  medal(year='1932', athlete="Patrick O'callaghan", team='IRL', event='hammer throw men'),
#  medal(year='1932', athlete='Duncan Mcnaughton', team='CAN', event='high jump men'),
#  medal(year='1932', athlete='Jean Shiley', team='USA', event='high jump women'),
#  medal(year='1932', athlete='Matti Henrik Jarvinen', team='FIN', event='javelin throw men'),
#  medal(year='1932', athlete='Mildred Didrikson', team='USA', event='javelin throw women'),
#  medal(year='1932', athlete='Edward Lansing Gordon', team='USA', event='long jump men'),
#  medal(year='1932', athlete='Juan Carlos Zabala', team='ARG', event='marathon men'),
#  medal(year='1932', athlete='William Waring Miller', team='USA', event='pole vault men'),
#  medal(year='1932', athlete='Leo Joseph Sexton', team='USA', event='shot put men'),
#  medal(year='1932', athlete='Chuhei Nambu', team='JPN', event='triple jump men'),
#  medal(year='1936', athlete='Ilmari Salminen', team='FIN', event='10000m men'),
#  medal(year='1936', athlete='Jesse Owens', team='USA', event='100m men'),
#  medal(year='1936', athlete='Helen Herring Stephens', team='USA', event='100m women'),
#  medal(year='1936', athlete='Forrest Grady Towns', team='USA', event='110m hurdles men'),
#  medal(year='1936', athlete='John Lovelock', team='NZL', event='1500m men'),
#  medal(year='1936', athlete='Jesse Owens', team='USA', event='200m men'),
#  medal(year='1936', athlete='Volmari Iso-Hollo', team='FIN', event='3000m steeplechase men'),
#  medal(year='1936', athlete='Archibald Franklin Williams', team='USA', event='400m men'),
#  medal(year='1936', athlete='Glenn Foster Hardin', team='USA', event='400m hurdles men'),
#  medal(year='1936', athlete='Foy Draper', team='USA', event='4x100m relay men'),
#  medal(year='1936', athlete='Ralph Metcalfe', team='USA', event='4x100m relay men'),
#  medal(year='1936', athlete='Jesse Owens', team='USA', event='4x100m relay men'),
#  medal(year='1936', athlete='Frank Clifford Wykoff', team='USA', event='4x100m relay men'),
#  medal(year='1936', athlete='Harriett Claiborne Bland', team='USA', event='4x100m relay women'),
#  medal(year='1936', athlete='Elizabeth Robinson', team='USA', event='4x100m relay women'),
#  medal(year='1936', athlete='Annette Joan Rogers', team='USA', event='4x100m relay women'),
#  medal(year='1936', athlete='Helen Herring Stephens', team='USA', event='4x100m relay women'),
#  medal(year='1936', athlete='Arthur Godfrey Kilner Brown', team='GBR', event='4x400m relay men'),
#  medal(year='1936', athlete='Godfrey Lionel Rampling', team='GBR', event='4x400m relay men'),
#  medal(year='1936', athlete='William Roberts', team='GBR', event='4x400m relay men'),
#  medal(year='1936', athlete='Frederick Ferdinand Wolff', team='GBR', event='4x400m relay men'),
#  medal(year='1936', athlete='Gunnar Höckert', team='FIN', event='5000m men'),
#  medal(year='1936', athlete='Hector Harold Whitlock', team='GBR', event='50km walk men'),
#  medal(year='1936', athlete='John Youie Woodruff', team='USA', event='800m men'),
#  medal(year='1936', athlete='Trebisonda Valla', team='ITA', event='80m hurdles women'),
#  medal(year='1936', athlete='Glenn Edward Morris', team='USA', event='decathlon men'),
#  medal(year='1936', athlete='William Kenneth Carpenter', team='USA', event='discus throw men'),
#  medal(year='1936', athlete='Gisela Mauermayer', team='GER', event='discus throw women'),
#  medal(year='1936', athlete='Karl Hein', team='GER', event='hammer throw men'),
#  medal(year='1936', athlete='Cornelius Cooper Johnson', team='USA', event='high jump men'),
#  medal(year='1936', athlete='Ibolya Csak', team='HUN', event='high jump women'),
#  medal(year='1936', athlete='Gerhard (Gerd) Stöck', team='GER', event='javelin throw men'),
#  medal(year='1936', athlete='Mathilde (Tilly) Fleischer', team='GER', event='javelin throw women'),
#  medal(year='1936', athlete='Jesse Owens', team='USA', event='long jump men'),
#  medal(year='1936', athlete='Kitei Son', team='JPN', event='marathon men'),
#  medal(year='1936', athlete='Earle Elmer Meadows', team='USA', event='pole vault men'),
#  medal(year='1936', athlete='Hans Woellke', team='GER', event='shot put men'),
#  medal(year='1936', athlete='Naoto Tajima', team='JPN', event='triple jump men'),
#  medal(year='1948', athlete='Emil Zatopek', team='TCH', event='10000m men'),
#  medal(year='1948', athlete='John Mikaelsson', team='SWE', event='10000m walk men'),
#  medal(year='1948', athlete='Harrison Dillard', team='USA', event='100m men'),
#  medal(year='1948', athlete='Fanny Blankers-Koen', team='NED', event='100m women'),
#  medal(year='1948', athlete='William Franklin III Porter', team='USA', event='110m hurdles men'),
#  medal(year='1948', athlete='Henry Eriksson', team='SWE', event='1500m men'),
#  medal(year='1948', athlete='Melvin Emery Patton', team='USA', event='200m men'),
#  medal(year='1948', athlete='Fanny Blankers-Koen', team='NED', event='200m women'),
#  medal(year='1948', athlete='Tore Sjöstrand', team='SWE', event='3000m steeplechase men'),
#  medal(year='1948', athlete='Arthur Wint', team='JAM', event='400m men'),
#  medal(year='1948', athlete='Roy Braxton Cochran', team='USA', event='400m hurdles men'),
#  medal(year='1948', athlete='Harrison Dillard', team='USA', event='4x100m relay men'),
#  medal(year='1948', athlete='Harold Norwood Ewell', team='USA', event='4x100m relay men'),
#  medal(year='1948', athlete='Melvin Emery Patton', team='USA', event='4x100m relay men'),
#  medal(year='1948', athlete='Lorenzo Christopher Wright', team='USA', event='4x100m relay men'),
#  medal(year='1948', athlete='Fanny Blankers-Koen', team='NED', event='4x100m relay women'),
#  medal(year='1948', athlete='Xenia Stad-De jong', team='NED', event='4x100m relay women'),
#  medal(year='1948', athlete='Gerda Johanna Marie Van der kade-Koudijs', team='NED', event='4x100m relay women'),
#  medal(year='1948', athlete='Jeannette Josephina Maria Witziers-Timmer', team='NED', event='4x100m relay women'),
#  medal(year='1948', athlete='Clifford Frederick Bourland', team='USA', event='4x400m relay men'),
#  medal(year='1948', athlete='Roy Braxton Cochran', team='USA', event='4x400m relay men'),
#  medal(year='1948', athlete='Arthur Harold Harnden', team='USA', event='4x400m relay men'),
#  medal(year='1948', athlete='Malvin Groston Whitfield', team='USA', event='4x400m relay men'),
#  medal(year='1948', athlete='Gaston Etienne Reiff', team='BEL', event='5000m men'),
#  medal(year='1948', athlete='John Artur Ljunggren', team='SWE', event='50km walk men'),
#  medal(year='1948', athlete='Malvin Groston Whitfield', team='USA', event='800m men'),
#  medal(year='1948', athlete='Fanny Blankers-Koen', team='NED', event='80m hurdles women'),
#  medal(year='1948', athlete='Robert Mathias', team='USA', event='decathlon men'),
#  medal(year='1948', athlete='Adolfo Consolini', team='ITA', event='discus throw men'),
#  medal(year='1948', athlete='Micheline Ostermeyer', team='FRA', event='discus throw women'),
#  medal(year='1948', athlete='Imre Nemeth', team='HUN', event='hammer throw men'),
#  medal(year='1948', athlete='John Winter', team='AUS', event='high jump men'),
#  medal(year='1948', athlete='Alice Marie Coachman', team='USA', event='high jump women'),
#  medal(year='1948', athlete='Kaj Tapio Rautavaara', team='FIN', event='javelin throw men'),
#  medal(year='1948', athlete='Hermine (Herma) Bauma', team='AUT', event='javelin throw women'),
#  medal(year='1948', athlete='William Samuel Steele', team='USA', event='long jump men'),
#  medal(year='1948', athlete='Olga Gyarmati', team='HUN', event='long jump women'),
#  medal(year='1948', athlete='Delfo Cabrera', team='ARG', event='marathon men'),
#  medal(year='1948', athlete='Owen Guinn Smith', team='USA', event='pole vault men'),
#  medal(year='1948', athlete='Wilbur Marvin Thompson', team='USA', event='shot put men'),
#  medal(year='1948', athlete='Micheline Ostermeyer', team='FRA', event='shot put women'),
#  medal(year='1948', athlete='Arne Ahman', team='SWE', event='triple jump men'),
#  medal(year='1952', athlete='Emil Zatopek', team='TCH', event='10000m men'),
#  medal(year='1952', athlete='John Mikaelsson', team='SWE', event='10000m walk men'),
#  medal(year='1952', athlete='Lindy Remigino', team='USA', event='100m men'),
#  medal(year='1952', athlete='Marjorie Jackson', team='AUS', event='100m women'),
#  medal(year='1952', athlete='Harrison Dillard', team='USA', event='110m hurdles men'),
#  medal(year='1952', athlete='Joseph Barthel', team='LUX', event='1500m men'),
#  medal(year='1952', athlete='Andrew William Stanfield', team='USA', event='200m men'),
#  medal(year='1952', athlete='Marjorie Jackson', team='AUS', event='200m women'),
#  medal(year='1952', athlete='Horace III Ashenfelter', team='USA', event='3000m steeplechase men'),
#  medal(year='1952', athlete='Vincent George Rhoden', team='JAM', event='400m men'),
#  medal(year='1952', athlete='Charles Hewes Jr. Moore', team='USA', event='400m hurdles men'),
#  medal(year='1952', athlete='Harrison Dillard', team='USA', event='4x100m relay men'),
#  medal(year='1952', athlete='Lindy Remigino', team='USA', event='4x100m relay men'),
#  medal(year='1952', athlete='Finis Dean Smith', team='USA', event='4x100m relay men'),
#  medal(year='1952', athlete='Andrew William Stanfield', team='USA', event='4x100m relay men'),
#  medal(year='1952', athlete='Mae Heriwentha Faggs', team='USA', event='4x100m relay women'),
#  medal(year='1952', athlete='Catherine Hardy', team='USA', event='4x100m relay women'),
#  medal(year='1952', athlete='Barbara Pearl Jones', team='USA', event='4x100m relay women'),
#  medal(year='1952', athlete='Janet Theresa Moreau', team='USA', event='4x100m relay women'),
#  medal(year='1952', athlete='Leslie Laing', team='JAM', event='4x400m relay men'),
#  medal(year='1952', athlete='Herbert Mckenley', team='JAM', event='4x400m relay men'),
#  medal(year='1952', athlete='Vincent George Rhoden', team='JAM', event='4x400m relay men'),
#  medal(year='1952', athlete='Arthur Wint', team='JAM', event='4x400m relay men'),
#  medal(year='1952', athlete='Emil Zatopek', team='TCH', event='5000m men'),
#  medal(year='1952', athlete='Giuseppe Dordoni', team='ITA', event='50km walk men'),
#  medal(year='1952', athlete='Malvin Groston Whitfield', team='USA', event='800m men'),
#  medal(year='1952', athlete='Shirley Strickland-De La Hunty', team='AUS', event='80m hurdles women'),
#  medal(year='1952', athlete='Robert Mathias', team='USA', event='decathlon men'),
#  medal(year='1952', athlete='Simeon Garland Iness', team='USA', event='discus throw men'),
#  medal(year='1952', athlete='Nina Romashkova-Ponomareva', team='URS', event='discus throw women'),
#  medal(year='1952', athlete='Jozsef Csermak', team='HUN', event='hammer throw men'),
#  medal(year='1952', athlete='Walter Francis Davis', team='USA', event='high jump men'),
#  medal(year='1952', athlete='Esther Cornelia Brand', team='RSA', event='high jump women'),
#  medal(year='1952', athlete='Cyrus C. Jr. Young', team='USA', event='javelin throw men'),
#  medal(year='1952', athlete='Dana Ingrova-Zatopkova', team='TCH', event='javelin throw women'),
#  medal(year='1952', athlete='Jerome Cousins Biffle', team='USA', event='long jump men'),
#  medal(year='1952', athlete='Yvette Winefred Williams', team='NZL', event='long jump women'),
#  medal(year='1952', athlete='Emil Zatopek', team='TCH', event='marathon men'),
#  medal(year='1952', athlete='Robert Richards', team='USA', event='pole vault men'),
#  medal(year='1952', athlete='William Patrick Jr. O', team='USA', event='shot put men'),
#  medal(year='1952', athlete='Galina Zybina', team='URS', event='shot put women'),
#  medal(year='1952', athlete='Adhemar Ferreira Da Silva', team='BRA', event='triple jump men'),
#  medal(year='1956', athlete='Vladimir Kuts', team='URS', event='10000m men'),
#  medal(year='1956', athlete='Robert Joseph Morrow', team='USA', event='100m men'),
#  medal(year='1956', athlete='Betty Cuthbert', team='AUS', event='100m women'),
#  medal(year='1956', athlete='Lee Calhoun', team='USA', event='110m hurdles men'),
#  medal(year='1956', athlete='Ronald Michael Delany', team='IRL', event='1500m men'),
#  medal(year='1956', athlete='Robert Joseph Morrow', team='USA', event='200m men'),
#  medal(year='1956', athlete='Betty Cuthbert', team='AUS', event='200m women'),
#  medal(year='1956', athlete='Leonid Spirin', team='URS', event='20km walk men'),
#  medal(year='1956', athlete='Christopher William Brasher', team='GBR', event='3000m steeplechase men'),
#  medal(year='1956', athlete='Charles Lamont Jenkins', team='USA', event='400m men'),
#  medal(year='1956', athlete='Glenn Ashby Davis', team='USA', event='400m hurdles men'),
#  medal(year='1956', athlete='Walter Thane Baker', team='USA', event='4x100m relay men'),
#  medal(year='1956', athlete='Leamon King', team='USA', event='4x100m relay men'),
#  medal(year='1956', athlete='Robert Joseph Morrow', team='USA', event='4x100m relay men'),
#  medal(year='1956', athlete='Ira James Murchison', team='USA', event='4x100m relay men'),
#  medal(year='1956', athlete='Norma Wilson Crooker-Fleming', team='AUS', event='4x100m relay women'),
#  medal(year='1956', athlete='Betty Cuthbert', team='AUS', event='4x100m relay women'),
#  medal(year='1956', athlete='Fluer Northey Mellor-Wenham', team='AUS', event='4x100m relay women'),
#  medal(year='1956', athlete='Shirley Strickland-De La Hunty', team='AUS', event='4x100m relay women'),
#  medal(year='1956', athlete='Thomas William Courtney', team='USA', event='4x400m relay men'),
#  medal(year='1956', athlete='Charles Lamont Jenkins', team='USA', event='4x400m relay men'),
#  medal(year='1956', athlete='Louis Woodard III Jones', team='USA', event='4x400m relay men'),
#  medal(year='1956', athlete='Jesse William Mashburn', team='USA', event='4x400m relay men'),
#  medal(year='1956', athlete='Vladimir Kuts', team='URS', event='5000m men'),
#  medal(year='1956', athlete='Norman Richard Read', team='NZL', event='50km walk men'),
#  medal(year='1956', athlete='Thomas William Courtney', team='USA', event='800m men'),
#  medal(year='1956', athlete='Shirley Strickland-De La Hunty', team='AUS', event='80m hurdles women'),
#  medal(year='1956', athlete='Milton Gray Campbell', team='USA', event='decathlon men'),
#  medal(year='1956', athlete='Alfred Oerter', team='USA', event='discus throw men'),
#  medal(year='1956', athlete='Olga Fikotova-Connolly', team='TCH', event='discus throw women'),
#  medal(year='1956', athlete='Harold Vincent Connolly', team='USA', event='hammer throw men'),
#  medal(year='1956', athlete='Charles Everett Dumas', team='USA', event='high jump men'),
#  medal(year='1956', athlete='Mildred Louise Mcdaniel', team='USA', event='high jump women'),
#  medal(year='1956', athlete='Egil Danielsen', team='NOR', event='javelin throw men'),
#  medal(year='1956', athlete='Inese Yaunzeme', team='URS', event='javelin throw women'),
#  medal(year='1956', athlete='Gregory Curtis Bell', team='USA', event='long jump men'),
#  medal(year='1956', athlete='Elzbieta Dunska-Krzesinska', team='POL', event='long jump women'),
#  medal(year='1956', athlete='Alain Mimoun', team='FRA', event='marathon men'),
#  medal(year='1956', athlete='Robert Richards', team='USA', event='pole vault men'),
#  medal(year='1956', athlete='William Patrick Jr. O', team='USA', event='shot put men'),
#  medal(year='1956', athlete='Tamara Tyshkevich', team='URS', event='shot put women'),
#  medal(year='1956', athlete='Adhemar Ferreira Da Silva', team='BRA', event='triple jump men'),
#  medal(year='1960', athlete='Pyotr Bolotnikov', team='URS', event='10000m men'),
#  medal(year='1960', athlete='Armin Hary', team='EUA', event='100m men'),
#  medal(year='1960', athlete='Wilma Rudolph', team='USA', event='100m women'),
#  medal(year='1960', athlete='Lee Calhoun', team='USA', event='110m hurdles men'),
#  medal(year='1960', athlete='Herbert Elliott', team='AUS', event='1500m men'),
#  medal(year='1960', athlete='Livio Berruti', team='ITA', event='200m men'),
#  medal(year='1960', athlete='Wilma Rudolph', team='USA', event='200m women'),
#  medal(year='1960', athlete='Vladimir Golubnichy', team='URS', event='20km walk men'),
#  medal(year='1960', athlete='Zdzislaw Krzyszkowiak', team='POL', event='3000m steeplechase men'),
#  medal(year='1960', athlete='Otis Crandall Davis', team='USA', event='400m men'),
#  medal(year='1960', athlete='Glenn Ashby Davis', team='USA', event='400m hurdles men'),
#  medal(year='1960', athlete='Bernd Cullmann', team='EUA', event='4x100m relay men'),
#  medal(year='1960', athlete='Armin Hary', team='EUA', event='4x100m relay men'),
#  medal(year='1960', athlete='Martin Lauer', team='EUA', event='4x100m relay men'),
#  medal(year='1960', athlete='Walter Mahlendorf', team='EUA', event='4x100m relay men'),
#  medal(year='1960', athlete='Martha B. Hudson', team='USA', event='4x100m relay women'),
#  medal(year='1960', athlete='Barbara Pearl Jones', team='USA', event='4x100m relay women'),
#  medal(year='1960', athlete='Wilma Rudolph', team='USA', event='4x100m relay women'),
#  medal(year='1960', athlete='Lucinda Williams', team='USA', event='4x100m relay women'),
#  medal(year='1960', athlete='Glenn Ashby Davis', team='USA', event='4x400m relay men'),
#  medal(year='1960', athlete='Otis Crandall Davis', team='USA', event='4x400m relay men'),
#  medal(year='1960', athlete='John Lloyd Yerman', team='USA', event='4x400m relay men'),
#  medal(year='1960', athlete='Earl Verdelle Young', team='USA', event='4x400m relay men'),
#  medal(year='1960', athlete='Murray Gordon Halberg', team='NZL', event='5000m men'),
#  medal(year='1960', athlete='Donald James Thompson', team='GBR', event='50km walk men'),
#  medal(year='1960', athlete='Peter Snell', team='NZL', event='800m men'),
#  medal(year='1960', athlete='Lyudmila Lisenko-Shevtsova', team='URS', event='800m women'),
#  medal(year='1960', athlete='Iryna Press', team='URS', event='80m hurdles women'),
#  medal(year='1960', athlete='Rafer Lewis Johnson', team='USA', event='decathlon men'),
#  medal(year='1960', athlete='Alfred Oerter', team='USA', event='discus throw men'),
#  medal(year='1960', athlete='Nina Romashkova-Ponomareva', team='URS', event='discus throw women'),
#  medal(year='1960', athlete='Vasili Rudenkov', team='URS', event='hammer throw men'),
#  medal(year='1960', athlete='Robert Shavlakadze', team='URS', event='high jump men'),
#  medal(year='1960', athlete='Iolanda Balas', team='ROU', event='high jump women'),
#  medal(year='1960', athlete='Viktor Tsybulenko', team='URS', event='javelin throw men'),
#  medal(year='1960', athlete='Elvira Ozolina', team='URS', event='javelin throw women'),
#  medal(year='1960', athlete='Ralph Harold Boston', team='USA', event='long jump men'),
#  medal(year='1960', athlete='Vera Kolashnikova-Krepkina', team='URS', event='long jump women'),
#  medal(year='1960', athlete='Abebe Bikila', team='ETH', event='marathon men'),
#  medal(year='1960', athlete='Donald George Bragg', team='USA', event='pole vault men'),
#  medal(year='1960', athlete='William Henry Nieder', team='USA', event='shot put men'),
#  medal(year='1960', athlete='Tamara Press', team='URS', event='shot put women'),
#  medal(year='1960', athlete='Jozef Schmidt', team='POL', event='triple jump men'),
#  medal(year='1964', athlete='William Mills', team='USA', event='10000m men'),
#  medal(year='1964', athlete='Robert Hayes', team='USA', event='100m men'),
#  medal(year='1964', athlete='Wyomia Tyus', team='USA', event='100m women'),
#  medal(year='1964', athlete='Hayes Jones', team='USA', event='110m hurdles men'),
#  medal(year='1964', athlete='Peter Snell', team='NZL', event='1500m men'),
#  medal(year='1964', athlete='Henry Carr', team='USA', event='200m men'),
#  medal(year='1964', athlete='Edith Marie Mcguire', team='USA', event='200m women'),
#  medal(year='1964', athlete='Kenneth Joseph Matthews', team='GBR', event='20km walk men'),
#  medal(year='1964', athlete='Gaston Roelants', team='BEL', event='3000m steeplechase men'),
#  medal(year='1964', athlete='Michael Denny Larrabee', team='USA', event='400m men'),
#  medal(year='1964', athlete='Betty Cuthbert', team='AUS', event='400m women'),
#  medal(year='1964', athlete='Warren (Rex) Jay Cawley', team='USA', event='400m hurdles men'),
#  medal(year='1964', athlete='Gerald Howard Ashworth', team='USA', event='4x100m relay men'),
#  medal(year='1964', athlete='Otis Paul Drayton', team='USA', event='4x100m relay men'),
#  medal(year='1964', athlete='Robert Hayes', team='USA', event='4x100m relay men'),
#  medal(year='1964', athlete='Richard Vaughn Stebbins', team='USA', event='4x100m relay men'),
#  medal(year='1964', athlete='Halina Herrmann-Gorecka-Richter', team='POL', event='4x100m relay women'),
#  medal(year='1964', athlete='Ewa Klobukowska', team='POL', event='4x100m relay women'),
#  medal(year='1964', athlete='Irena Szewinska', team='POL', event='4x100m relay women'),
#  medal(year='1964', athlete='Teresa Barbara Wieczorek-Cieply', team='POL', event='4x100m relay women'),
#  medal(year='1964', athlete='Henry Carr', team='USA', event='4x400m relay men'),
#  medal(year='1964', athlete='Ollan Conley Cassell', team='USA', event='4x400m relay men'),
#  medal(year='1964', athlete='Michael Denny Larrabee', team='USA', event='4x400m relay men'),
#  medal(year='1964', athlete='Ulis C. Williams', team='USA', event='4x400m relay men'),
#  medal(year='1964', athlete='Robert Keyser Schul', team='USA', event='5000m men'),
#  medal(year='1964', athlete='Abdon Pamich', team='ITA', event='50km walk men'),
#  medal(year='1964', athlete='Peter Snell', team='NZL', event='800m men'),
#  medal(year='1964', athlete='Ann Elizabeth Packer', team='GBR', event='800m women'),
#  medal(year='1964', athlete='Karin Richert-Balzer', team='EUA', event='80m hurdles women'),
#  medal(year='1964', athlete='Willi Holdorf', team='EUA', event='decathlon men'),
#  medal(year='1964', athlete='Alfred Oerter', team='USA', event='discus throw men'),
#  medal(year='1964', athlete='Tamara Press', team='URS', event='discus throw women'),
#  medal(year='1964', athlete='Romuald Klim', team='URS', event='hammer throw men'),
#  medal(year='1964', athlete='Valeri Brumel', team='URS', event='high jump men'),
#  medal(year='1964', athlete='Iolanda Balas', team='ROU', event='high jump women'),
#  medal(year='1964', athlete='Pauli Lauri Nevala', team='FIN', event='javelin throw men'),
#  medal(year='1964', athlete='Mihaela Penes', team='ROU', event='javelin throw women'),
#  medal(year='1964', athlete='Lynn Davies', team='GBR', event='long jump men'),
#  medal(year='1964', athlete='Mary Denise Bignal-Rand', team='GBR', event='long jump women'),
#  medal(year='1964', athlete='Abebe Bikila', team='ETH', event='marathon men'),
#  medal(year='1964', athlete='Iryna Press', team='URS', event='pentathlon women'),
#  medal(year='1964', athlete='Frederick Morgan Hansen', team='USA', event='pole vault men'),
#  medal(year='1964', athlete='Dallas Crutcher III Long', team='USA', event='shot put men'),
#  medal(year='1964', athlete='Tamara Press', team='URS', event='shot put women'),
#  medal(year='1964', athlete='Jozef Schmidt', team='POL', event='triple jump men'),
#  medal(year='1968', athlete='Nabiba Naftali Temu', team='KEN', event='10000m men'),
# ...
#  medal(year='1988', athlete='Julius Kariuki', team='KEN', event='3000m steeplechase men'),
#  medal(year='1988', athlete='Steve Lewis', team='USA', event='400m men'),
#  medal(year='1988', athlete='Olga Bryzgina', team='URS', event='400m women'),
#  medal(year='1988', athlete='Andre Lamar Phillips', team='USA', event='400m hurdles men'),
#  medal(year='1988', athlete='Deborah Flintoff-King', team='AUS', event='400m hurdles women'),
#  medal(year='1988', athlete='Viktor Bryzgin', team='URS', event='4x100m relay men'),
#  medal(year='1988', athlete='Vladimir Krylov', team='URS', event='4x100m relay men'),
#  medal(year='1988', athlete='Vladimir Muravyov', team='URS', event='4x100m relay men'),
#  medal(year='1988', athlete='Vitaly Savin', team='URS', event='4x100m relay men'),
#  medal(year='1988', athlete='Evelyn Ashford', team='USA', event='4x100m relay women'),
#  medal(year='1988', athlete='Alice Regina Brown', team='USA', event='4x100m relay women'),
#  medal(year='1988', athlete='Sheila Echols', team='USA', event='4x100m relay women'),
#  medal(year='1988', athlete='Florence Griffith-Joyner', team='USA', event='4x100m relay women'),
#  medal(year='1988', athlete='Daniel Everett', team='USA', event='4x400m relay men'),
#  medal(year='1988', athlete='Steve Lewis', team='USA', event='4x400m relay men'),
#  medal(year='1988', athlete='Harry Butch . Reynolds', team='USA', event='4x400m relay men'),
#  medal(year='1988', athlete='Kevin Bernard Robinzine', team='USA', event='4x400m relay men'),
#  medal(year='1988', athlete='Olga Bryzgina', team='URS', event='4x400m relay women'),
#  medal(year='1988', athlete='Tatiana Ledovskaya', team='URS', event='4x400m relay women'),
#  medal(year='1988', athlete='Olga Nazarova', team='URS', event='4x400m relay women'),
#  medal(year='1988', athlete='Mariya Pinigina', team='URS', event='4x400m relay women'),
#  medal(year='1988', athlete='John Ngugi', team='KEN', event='5000m men'),
#  medal(year='1988', athlete='Vyacheslav Ivanenko', team='URS', event='50km walk men'),
#  medal(year='1988', athlete='Paul Ereng', team='KEN', event='800m men'),
#  medal(year='1988', athlete='Sigrun Wodars', team='GDR', event='800m women'),
#  medal(year='1988', athlete='Christian Schenk', team='GDR', event='decathlon men'),
#  medal(year='1988', athlete='Jürgen Schult', team='GDR', event='discus throw men'),
#  medal(year='1988', athlete='Martina Hellmann', team='GDR', event='discus throw women'),
#  medal(year='1988', athlete='Sergei Litvinov', team='URS', event='hammer throw men'),
#  medal(year='1988', athlete='Jackie Joyner-Kersee', team='USA', event='heptathlon women'),
#  medal(year='1988', athlete='Gennadi Avdeenko', team='URS', event='high jump men'),
#  medal(year='1988', athlete='Dorothy Louise Ritter', team='USA', event='high jump women'),
#  medal(year='1988', athlete='Tapio Korjus', team='FIN', event='javelin throw men'),
#  medal(year='1988', athlete='Petra Felke-Meier', team='GDR', event='javelin throw women'),
#  medal(year='1988', athlete='Carl Lewis', team='USA', event='long jump men'),
#  medal(year='1988', athlete='Jackie Joyner-Kersee', team='USA', event='long jump women'),
#  medal(year='1988', athlete='Gelindo Bordin', team='ITA', event='marathon men'),
#  medal(year='1988', athlete='Rosa Mota', team='POR', event='marathon women'),
#  medal(year='1988', athlete='Sergey Bubka', team='URS', event='pole vault men'),
#  medal(year='1988', athlete='Ulf Timmermann', team='GDR', event='shot put men'),
#  medal(year='1988', athlete='Natalya Lisovskaya', team='URS', event='shot put women'),
#  medal(year='1988', athlete='Kristo Gantchev Markov', team='BUL', event='triple jump men'),
#  medal(year='1992', athlete='Khalid Skah', team='MAR', event='10000m men'),
#  medal(year='1992', athlete='Derartu Tulu', team='ETH', event='10000m women'),
#  medal(year='1992', athlete='Yueling Chen', team='CHN', event='10000m walk women'),
#  medal(year='1992', athlete='Linford Christie', team='GBR', event='100m men'),
#  medal(year='1992', athlete='Gail Devers', team='USA', event='100m women'),
#  medal(year='1992', athlete='Paraskevi Voula Patoulidou', team='GRE', event='100m hurdles women'),
#  medal(year='1992', athlete='Mark Mckoy', team='CAN', event='110m hurdles men'),
#  medal(year='1992', athlete='Fermin Cacho ruiz', team='ESP', event='1500m men'),
#  medal(year='1992', athlete='Hassiba Boulmerka', team='ALG', event='1500m women'),
#  medal(year='1992', athlete='Michael Marsh', team='USA', event='200m men'),
#  medal(year='1992', athlete='Gwen Torrence', team='USA', event='200m women'),
#  medal(year='1992', athlete='Daniel Plaza montero', team='ESP', event='20km walk men'),
#  medal(year='1992', athlete='Elena Romanova', team='EUN', event='3000m women'),
#  medal(year='1992', athlete='Mathew Birir', team='KEN', event='3000m steeplechase men'),
#  medal(year='1992', athlete='Quincy Watts', team='USA', event='400m men'),
#  medal(year='1992', athlete='Marie-Jose Perec', team='FRA', event='400m women'),
#  medal(year='1992', athlete='Kevin Curtis Young', team='USA', event='400m hurdles men'),
#  medal(year='1992', athlete='Sally Janet Jane Gunnell', team='GBR', event='400m hurdles women'),
#  medal(year='1992', athlete='Leroy Burrell', team='USA', event='4x100m relay men'),
#  medal(year='1992', athlete='James Jett', team='USA', event='4x100m relay men'),
#  medal(year='1992', athlete='Carl Lewis', team='USA', event='4x100m relay men'),
#  medal(year='1992', athlete='Michael Marsh', team='USA', event='4x100m relay men'),
#  medal(year='1992', athlete='Dennis Mitchell', team='USA', event='4x100m relay men'),
#  medal(year='1992', athlete='Evelyn Ashford', team='USA', event='4x100m relay women'),
#  medal(year='1992', athlete='Michelle Finn', team='USA', event='4x100m relay women'),
#  medal(year='1992', athlete='Carlette D. Guidry-White', team='USA', event='4x100m relay women'),
#  medal(year='1992', athlete='Esther Jones', team='USA', event='4x100m relay women'),
#  medal(year='1992', athlete='Gwen Torrence', team='USA', event='4x100m relay women'),
#  medal(year='1992', athlete='Darnell Hall', team='USA', event='4x400m relay men'),
#  medal(year='1992', athlete='Charles L. Jenkins', team='USA', event='4x400m relay men'),
#  medal(year='1992', athlete='Michael Johnson', team='USA', event='4x400m relay men'),
#  medal(year='1992', athlete='Steve Lewis', team='USA', event='4x400m relay men'),
#  medal(year='1992', athlete='Andrew Valmon', team='USA', event='4x400m relay men'),
#  medal(year='1992', athlete='Quincy Watts', team='USA', event='4x400m relay men'),
#  medal(year='1992', athlete='Olga Bryzgina', team='EUN', event='4x400m relay women'),
#  medal(year='1992', athlete='Marina Chmonina', team='EUN', event='4x400m relay women'),
#  medal(year='1992', athlete='Lioudmila Djigalova', team='EUN', event='4x400m relay women'),
#  medal(year='1992', athlete='Olga Nazarova', team='EUN', event='4x400m relay women'),
#  medal(year='1992', athlete='Lilia Nurutdinova', team='EUN', event='4x400m relay women'),
#  medal(year='1992', athlete='Yelena Rouzina', team='EUN', event='4x400m relay women'),
#  medal(year='1992', athlete='Dieter Baumann', team='GER', event='5000m men'),
#  medal(year='1992', athlete='Andrey Perlov', team='EUN', event='50km walk men'),
#  medal(year='1992', athlete='William Tanui', team='KEN', event='800m men'),
#  medal(year='1992', athlete='Ellen Van langen', team='NED', event='800m women'),
#  medal(year='1992', athlete='Robert Zmelik', team='TCH', event='decathlon men'),
#  medal(year='1992', athlete='Romas Ubartas', team='LTU', event='discus throw men'),
#  medal(year='1992', athlete='Maritza Marten', team='CUB', event='discus throw women'),
#  medal(year='1992', athlete='Andrey Abduvaliev', team='EUN', event='hammer throw men'),
#  medal(year='1992', athlete='Jackie Joyner-Kersee', team='USA', event='heptathlon women'),
#  medal(year='1992', athlete='Javier Sotomayor', team='CUB', event='high jump men'),
#  medal(year='1992', athlete='Heike Henkel', team='GER', event='high jump women'),
#  medal(year='1992', athlete='Jan Zelezny', team='TCH', event='javelin throw men'),
#  medal(year='1992', athlete='Silke Renk', team='GER', event='javelin throw women'),
#  medal(year='1992', athlete='Carl Lewis', team='USA', event='long jump men'),
#  medal(year='1992', athlete='Heike Drechsler', team='GER', event='long jump women'),
#  medal(year='1992', athlete='Young-Cho Hwang', team='KOR', event='marathon men'),
#  medal(year='1992', athlete='Valentina Yegorova', team='EUN', event='marathon women'),
#  medal(year='1992', athlete='Maksim Tarasov', team='EUN', event='pole vault men'),
#  medal(year='1992', athlete='Michael D. Stulce', team='USA', event='shot put men'),
#  medal(year='1992', athlete='Svetlana Krivelyova', team='EUN', event='shot put women'),
#  medal(year='1992', athlete='Mike Conley', team='USA', event='triple jump men'),
#  medal(year='1996', athlete='Haile Gebrselassie', team='ETH', event='10000m men'),
#  medal(year='1996', athlete='Fernanda Ribeiro', team='POR', event='10000m women'),
#  medal(year='1996', athlete='Yelena Nikolayeva', team='RUS', event='10000m walk women'),
#  medal(year='1996', athlete='Donovan Bailey', team='CAN', event='100m men'),
#  medal(year='1996', athlete='Gail Devers', team='USA', event='100m women'),
#  medal(year='1996', athlete='Ludmila Engquist', team='SWE', event='100m hurdles women'),
#  medal(year='1996', athlete='Allen Johnson', team='USA', event='110m hurdles men'),
#  medal(year='1996', athlete='Nourredine Morceli', team='ALG', event='1500m men'),
#  medal(year='1996', athlete='Svetlana Masterkova', team='RUS', event='1500m women'),
#  medal(year='1996', athlete='Michael Johnson', team='USA', event='200m men'),
#  medal(year='1996', athlete='Marie-Jose Perec', team='FRA', event='200m women'),
#  medal(year='1996', athlete='Jefferson Perez', team='ECU', event='20km walk men'),
#  medal(year='1996', athlete='Joseph Keter', team='KEN', event='3000m steeplechase men'),
#  medal(year='1996', athlete='Michael Johnson', team='USA', event='400m men'),
#  medal(year='1996', athlete='Marie-Jose Perec', team='FRA', event='400m women'),
#  medal(year='1996', athlete='Derrick Adkins', team='USA', event='400m hurdles men'),
#  medal(year='1996', athlete='Deon Marie Hemmings', team='JAM', event='400m hurdles women'),
#  medal(year='1996', athlete='Donovan Bailey', team='CAN', event='4x100m relay men'),
#  medal(year='1996', athlete='Carlton Chambers', team='CAN', event='4x100m relay men'),
#  medal(year='1996', athlete='Robert Esmie', team='CAN', event='4x100m relay men'),
#  medal(year='1996', athlete='Glenroy Gilbert', team='CAN', event='4x100m relay men'),
#  medal(year='1996', athlete='Bruny Surin', team='CAN', event='4x100m relay men'),
#  medal(year='1996', athlete='Gail Devers', team='USA', event='4x100m relay women'),
#  medal(year='1996', athlete='Chryste Gaines', team='USA', event='4x100m relay women'),
#  medal(year='1996', athlete='Carlette D. Guidry-White', team='USA', event='4x100m relay women'),
#  medal(year='1996', athlete='Inger Miller', team='USA', event='4x100m relay women'),
#  medal(year='1996', athlete='Gwen Torrence', team='USA', event='4x100m relay women'),
#  medal(year='1996', athlete='Alvin Harrison', team='USA', event='4x400m relay men'),
#  medal(year='1996', athlete='Anthuan Maybank', team='USA', event='4x400m relay men'),
#  medal(year='1996', athlete='Derek Mills', team='USA', event='4x400m relay men'),
#  medal(year='1996', athlete='Jason Rouser', team='USA', event='4x400m relay men'),
#  medal(year='1996', athlete='Lamont Smith', team='USA', event='4x400m relay men'),
#  medal(year='1996', athlete='Kim Graham', team='USA', event='4x400m relay women'),
#  medal(year='1996', athlete='Maicel Malone', team='USA', event='4x400m relay women'),
#  medal(year='1996', athlete='Jearl Miles', team='USA', event='4x400m relay women'),
#  medal(year='1996', athlete='Rochelle Stevens', team='USA', event='4x400m relay women'),
#  medal(year='1996', athlete='Linetta Wilson', team='USA', event='4x400m relay women'),
#  medal(year='1996', athlete='Venuste Niyongabo', team='BDI', event='5000m men'),
#  medal(year='1996', athlete='Junxia Wang', team='CHN', event='5000m women'),
#  medal(year='1996', athlete='Robert Korzeniowski', team='POL', event='50km walk men'),
#  medal(year='1996', athlete='Vebjorn Rodal', team='NOR', event='800m men'),
#  medal(year='1996', athlete='Svetlana Masterkova', team='RUS', event='800m women'),
#  medal(year='1996', athlete="Dan O'brien", team='USA', event='decathlon men'),
#  medal(year='1996', athlete='Lars Riedel', team='GER', event='discus throw men'),
#  medal(year='1996', athlete='Ilke Wyludda', team='GER', event='discus throw women'),
#  medal(year='1996', athlete='Balazs Kiss', team='HUN', event='hammer throw men'),
#  medal(year='1996', athlete='Ghada Shouaa', team='SYR', event='heptathlon women'),
#  medal(year='1996', athlete='Charles Austin', team='USA', event='high jump men'),
#  medal(year='1996', athlete='Stefka Kostadinova', team='BUL', event='high jump women'),
#  medal(year='1996', athlete='Jan Zelezny', team='CZE', event='javelin throw men'),
#  medal(year='1996', athlete='Heli Orvokki Rantanen', team='FIN', event='javelin throw women'),
#  medal(year='1996', athlete='Carl Lewis', team='USA', event='long jump men'),
#  medal(year='1996', athlete='Chioma Ajunwa', team='NGR', event='long jump women'),
#  medal(year='1996', athlete='Josia Thugwane', team='RSA', event='marathon men'),
#  medal(year='1996', athlete='Fatuma Roba', team='ETH', event='marathon women'),
#  medal(year='1996', athlete='Jean Galfione', team='FRA', event='pole vault men'),
#  medal(year='1996', athlete='Eric Randolph Barnes', team='USA', event='shot put men'),
#  medal(year='1996', athlete='Astrid Kumbernuss', team='GER', event='shot put women'),
#  medal(year='1996', athlete='Kenny Harrison', team='USA', event='triple jump men'),
#  medal(year='1996', athlete='Inessa Kravets', team='UKR', event='triple jump women'),
#  medal(year='2000', athlete='Haile Gebrselassie', team='ETH', event='10000m men'),
#  medal(year='2000', athlete='Derartu Tulu', team='ETH', event='10000m women'),
#  medal(year='2000', athlete='Maurice Greene', team='USA', event='100m men'),
#  medal(year='2000', athlete='Olga Shishigina', team='KAZ', event='100m hurdles women'),
#  medal(year='2000', athlete='Anier Garcia', team='CUB', event='110m hurdles men'),
#  medal(year='2000', athlete='Noah Kiprono Ngenyi', team='KEN', event='1500m men'),
#  medal(year='2000', athlete='Nouria Merah-Benida', team='ALG', event='1500m women'),
#  medal(year='2000', athlete='Konstantinos Kenteris', team='GRE', event='200m men'),
#  medal(year='2000', athlete='Pauline Elaine Davis', team='BAH', event='200m women'),
#  medal(year='2000', athlete='Liping Wang', team='CHN', event='20km race walk women'),
#  medal(year='2000', athlete='Robert Korzeniowski', team='POL', event='20km walk men'),
#  medal(year='2000', athlete='Reuben Kosgei', team='KEN', event='3000m steeplechase men'),
#  medal(year='2000', athlete='Michael Johnson', team='USA', event='400m men'),
#  medal(year='2000', athlete='Cathy Freeman', team='AUS', event='400m women'),
#  medal(year='2000', athlete='Angelo Taylor', team='USA', event='400m hurdles men'),
#  medal(year='2000', athlete='Irina Privalova', team='RUS', event='400m hurdles women'),
#  medal(year='2000', athlete='Kenneth Brokenburr', team='USA', event='4x100m relay men'),
#  medal(year='2000', athlete='Jon Drummond', team='USA', event='4x100m relay men'),
#  medal(year='2000', athlete='Maurice Greene', team='USA', event='4x100m relay men'),
#  medal(year='2000', athlete='Brian Lewis', team='USA', event='4x100m relay men'),
#  medal(year='2000', athlete='Tim Montgomery', team='USA', event='4x100m relay men'),
#  medal(year='2000', athlete='Bernard Williams iii', team='USA', event='4x100m relay men'),
#  medal(year='2000', athlete='Pauline Elaine Davis', team='BAH', event='4x100m relay women'),
#  medal(year='2000', athlete='Debbie Ferguson-Mckenzie', team='BAH', event='4x100m relay women'),
#  medal(year='2000', athlete='Sevatheda Fynes', team='BAH', event='4x100m relay women'),
#  medal(year='2000', athlete='Eldice Lewis', team='BAH', event='4x100m relay women'),
#  ...]

# %%
help(collections.UserString)
# Out:
# Help on class UserString in module collections:
#
# class UserString(collections.abc.Sequence)
#  |  UserString(seq)
#  |
#  |  All the operations on a read-only sequence.
#  |
#  |  Concrete subclasses must override __new__ or __init__,
#  |  __getitem__, and __len__.
#  |
#  |  Method resolution order:
#  |      UserString
#  |      collections.abc.Sequence
#  |      collections.abc.Reversible
#  |      collections.abc.Collection
#  |      collections.abc.Sized
#  |      collections.abc.Iterable
#  |      collections.abc.Container
#  |      builtins.object
#  |
#  |  Methods defined here:
#  |
#  |  __add__(self, other)
#  |
#  |  __complex__(self)
#  |
#  |  __contains__(self, char)
#  |
#  |  __eq__(self, string)
#  |      Return self==value.
#  |
#  |  __float__(self)
#  |
#  |  __ge__(self, string)
#  |      Return self>=value.
#  |
#  |  __getitem__(self, index)
#  |
#  |  __getnewargs__(self)
#  |
#  |  __gt__(self, string)
#  |      Return self>value.
#  |
#  |  __hash__(self)
#  |      Return hash(self).
#  |
#  |  __init__(self, seq)
#  |      Initialize self.  See help(type(self)) for accurate signature.
#  |
#  |  __int__(self)
#  |
#  |  __le__(self, string)
#  |      Return self<=value.
#  |
#  |  __len__(self)
#  |
#  |  __lt__(self, string)
#  |      Return self<value.
#  |
#  |  __mod__(self, args)
#  |
#  |  __mul__(self, n)
#  |
#  |  __radd__(self, other)
#  |
#  |  __repr__(self)
#  |      Return repr(self).
#  |
#  |  __rmod__(self, format)
#  |
#  |  __rmul__ = __mul__(self, n)
#  |
#  |  __str__(self)
#  |      Return str(self).
#  |
#  |  capitalize(self)
#  |      # the following methods are defined in alphabetical order:
#  |
#  |  casefold(self)
#  |
#  |  center(self, width, *args)
#  |
#  |  count(self, sub, start=0, end=9223372036854775807)
#  |      S.count(value) -> integer -- return number of occurrences of value
#  |
#  |  encode(self, encoding=None, errors=None)
#  |
#  |  endswith(self, suffix, start=0, end=9223372036854775807)
#  |
#  |  expandtabs(self, tabsize=8)
#  |
#  |  find(self, sub, start=0, end=9223372036854775807)
#  |
#  |  format(self, *args, **kwds)
#  |
#  |  format_map(self, mapping)
#  |
#  |  index(self, sub, start=0, end=9223372036854775807)
#  |      S.index(value, [start, [stop]]) -> integer -- return first index of value.
#  |      Raises ValueError if the value is not present.
#  |
#  |      Supporting start and stop arguments is optional, but
#  |      recommended.
#  |
#  |  isalnum(self)
#  |
#  |  isalpha(self)
#  |
#  |  isascii(self)
#  |
#  |  isdecimal(self)
#  |
#  |  isdigit(self)
#  |
#  |  isidentifier(self)
#  |
#  |  islower(self)
#  |
#  |  isnumeric(self)
#  |
#  |  isprintable(self)
#  |
#  |  isspace(self)
#  |
#  |  istitle(self)
#  |
#  |  isupper(self)
#  |
#  |  join(self, seq)
#  |
#  |  ljust(self, width, *args)
#  |
#  |  lower(self)
#  |
#  |  lstrip(self, chars=None)
#  |
#  |  partition(self, sep)
#  |
#  |  replace(self, old, new, maxsplit=-1)
#  |
#  |  rfind(self, sub, start=0, end=9223372036854775807)
#  |
#  |  rindex(self, sub, start=0, end=9223372036854775807)
#  |
#  |  rjust(self, width, *args)
#  |
#  |  rpartition(self, sep)
#  |
#  |  rsplit(self, sep=None, maxsplit=-1)
#  |
#  |  rstrip(self, chars=None)
#  |
#  |  split(self, sep=None, maxsplit=-1)
#  |
#  |  splitlines(self, keepends=False)
#  |
#  |  startswith(self, prefix, start=0, end=9223372036854775807)
#  |
#  |  strip(self, chars=None)
#  |
#  |  swapcase(self)
#  |
#  |  title(self)
#  |
#  |  translate(self, *args)
#  |
#  |  upper(self)
#  |
#  |  zfill(self, width)
#  |
#  |  ----------------------------------------------------------------------
#  |  Static methods defined here:
#  |
#  |  maketrans(x, y=None, z=None, /)
#  |      Return a translation table usable for str.translate().
#  |
#  |      If there is only one argument, it must be a dictionary mapping Unicode
#  |      ordinals (integers) or characters to Unicode ordinals, strings or None.
#  |      Character keys will be then converted to ordinals.
#  |      If there are two arguments, they must be strings of equal length, and
#  |      in the resulting dictionary, each character in x will be mapped to the
#  |      character at the same position in y. If there is a third argument, it
#  |      must be a string, whose characters will be mapped to None in the result.
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors defined here:
#  |
#  |  __dict__
#  |      dictionary for instance variables (if defined)
#  |
#  |  __weakref__
#  |      list of weak references to the object (if defined)
#  |
#  |  ----------------------------------------------------------------------
#  |  Data and other attributes defined here:
#  |
#  |  __abstractmethods__ = frozenset()
#  |
#  |  ----------------------------------------------------------------------
#  |  Methods inherited from collections.abc.Sequence:
#  |
#  |  __iter__(self)
#  |
#  |  __reversed__(self)
#  |
#  |  ----------------------------------------------------------------------
#  |  Class methods inherited from collections.abc.Reversible:
#  |
#  |  __subclasshook__(C) from abc.ABCMeta
#  |      Abstract classes can override this to customize issubclass().
#  |
#  |      This is invoked early on by abc.ABCMeta.__subclasscheck__().
#  |      It should return True, False or NotImplemented.  If it returns
#  |      NotImplemented, the normal algorithm is used.  Otherwise, it
#  |      overrides the normal algorithm (and the outcome is cached).

# %%
c = collections.Counter(medal.athlete for medal in medals)

# %%
c.most_common(5)
# Out:
# [(medal(year='1896', athlete='Thomas Burke', team='USA', event='100m men'), 1),
#  (medal(year='1896', athlete='Thomas Curtis', team='USA', event='110m hurdles men'),
#   1),
#  (medal(year='1896', athlete='Edwin Flack', team='AUS', event='1500m men'), 1),
#  (medal(year='1896', athlete='Thomas Burke', team='USA', event='400m men'), 1),
#  (medal(year='1896', athlete='Edwin Flack', team='AUS', event='800m men'), 1)]

# %%
def foo(med_info):
